# %%
import ast
import pandas as pd
from datasets import load_dataset

# %%
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# %%
df.sample(5)
# Out:
#        job_title_short                                 job_title  \
# 445181    Data Analyst               data analyst- charlotte, nc
# 397456    Data Analyst  Data Analyst Revenue Management in Stage
# 772890  Data Scientist                   Research Data Scientist
# 490510    Data Analyst                    Logistics Data Analyst
# 592874  Data Scientist                        Data Scientist H/F
#
#                          job_location                 job_via  \
# 445181                  Charlotte, NC               via Nexxt
# 397456                          Italy  via Lavoro Trabajo.org
# 772890          Saskatoon, SK, Canada        via BeBee Canada
# 490510  Monterrey, Nuevo Leon, Mexico        via BeBee México
# 592874                 Poissy, France            via LinkedIn
#
#        job_schedule_type  job_work_from_home search_location  \
# 445181        Contractor               False         Georgia
# 397456         Full-time               False           Italy
# 772890         Full-time               False          Canada
# 490510         Full-time               False          Mexico
# 592874         Full-time               False          France
#
#             job_posted_date  job_no_degree_mention  job_health_insurance  \
# 445181  2023-01-21 17:20:02                  False                  True
# 397456  2023-06-06 18:29:46                  False                 False
# 772890  2023-08-20 01:11:18                  False                 False
# 490510  2023-06-12 11:36:29                  False                 False
# 592874  2023-05-07 09:46:43                  False                 False
#
#           job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 445181  United States        None              NaN              NaN
# 397456          Italy        None              NaN              NaN
# 772890         Canada        None              NaN              NaN
# 490510         Mexico        None              NaN              NaN
# 592874         France        None              NaN              NaN
#
#                       company_name  \
# 445181                 Randstad US
# 397456        Optima Italia S.p.A.
# 772890  Canadian Light Source Inc.
# 490510       Charger Logistics Inc
# 592874                  Stellantis
#
#                                                job_skills  \
# 445181                                               None
# 397456               ['sql', 'r', 'python', 'sas', 'sas']
# 772890  ['python', 'pytorch', 'tensorflow', 'pandas', ...
# 490510                                               None
# 592874  ['python', 'databricks', 'snowflake', 'scikit-...
#
#                                           job_type_skills
# 445181                                               None
# 397456  {'analyst_tools': ['sas'], 'programming': ['sq...
# 772890  {'libraries': ['pytorch', 'tensorflow', 'panda...
# 490510                                               None
# 592874  {'cloud': ['databricks', 'snowflake'], 'librar...

# %%
df["job_posted_date"] = pd.to_datetime(df["job_posted_date"])

# Extract day, month, and year
df["job_posted_day"] = df["job_posted_date"].dt.day_name()
df["job_posted_month"] = df["job_posted_date"].dt.strftime("%B")
df["job_posted_month_no"] = df["job_posted_date"].dt.month
df["job_posted_year"] = df["job_posted_date"].dt.year

# %%
df.sort_values(by=["job_posted_year", "job_posted_month", "job_posted_day"], 
                           ascending=[True, True, True], 
                            inplace=True )

# %%
median_hour_salary = df.salary_hour_avg.median()

df["salary_hour_avg"] = df["salary_hour_avg"].fillna(median_hour_salary)

df.drop_duplicates(subset=['job_title' , 'company_name'], inplace=True)

# %%
df.to_csv("cleaned_data.csv", index=False)
