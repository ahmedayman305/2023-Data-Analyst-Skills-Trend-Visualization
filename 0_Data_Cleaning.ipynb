# %%
import ast
import pandas as pd
from datasets import load_dataset

# %%
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# %%
df.sample(5)
# Out:
#        job_title_short                   job_title               job_location  \
# 315209    Data Analyst  Business Data Analyst - IV            Jersey City, NJ
# 554806  Data Scientist              Data Scientist              Paris, France
# 415331  Data Scientist    Data engineer specialist          Bangkok, Thailand
# 267804   Data Engineer  Data Engineer Big Data H/F        Montpellier, France
# 335180   Data Engineer                 DATA EXPERT  Ho Chi Minh City, Vietnam
#
#                   job_via job_schedule_type  job_work_from_home  \
# 315209          via Lensa         Full-time               False
# 554806          via BeBee         Full-time               False
# 415331  via Jobtopgun.com         Full-time               False
# 267804       via Jobijoba         Full-time               False
# 335180         via TopDev         Full-time               False
#
#                 search_location      job_posted_date  job_no_degree_mention  \
# ...

# %%
df["job_posted_date"] = pd.to_datetime(df["job_posted_date"])

# Extract day, month, and year
df["job_posted_day"] = df["job_posted_date"].dt.day_name()
df["job_posted_month"] = df["job_posted_date"].dt.strftime("%B")
df["job_posted_month_no"] = df["job_posted_date"].dt.month
df["job_posted_year"] = df["job_posted_date"].dt.year

# %%
df.sort_values(by=["job_posted_year", "job_posted_month", "job_posted_day"], 
                           ascending=[True, True, True], 
                            inplace=True )

# %%
median_hour_salary = df.salary_hour_avg.median()

df["salary_hour_avg"] = df["salary_hour_avg"].fillna(median_hour_salary)

df.drop_duplicates(subset=['job_title' , 'company_name'], inplace=True)

# %%
df.sample(10).to_csv("cleaned_data.csv", index=False)
