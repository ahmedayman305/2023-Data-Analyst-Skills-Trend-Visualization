# %%
import ast
import pandas as pd
from datasets import load_dataset

# %%
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# %%
df.sample(5)
# Out:
#               job_title_short  \
# 528548           Data Analyst
# 531813           Data Analyst
# 11980   Senior Data Scientist
# 134496         Data Scientist
# 359312          Data Engineer
#
#                                                 job_title  \
# 528548                   IoT - Field Application Engineer
# 531813                        Client Success Data Analyst
# 11980   Senior Data Scientist - Poland - Freelance - H...
# 134496  Data Scientist/Behavioural Economist - App Sta...
# 359312                                      Data Engineer
#
#                   job_location                    job_via job_schedule_type  \
# 528548  Amsterdam, Netherlands  via Vacatures Trabajo.org         Full-time
# 531813             Chicago, IL                 via Indeed         Full-time
# 11980           Warsaw, Poland              via KSNT Jobs        Contractor
# 134496      Maharashtra, India                  via Shine         Full-time
# 359312             Newport, UK              via WANE Jobs         Full-time
#
#         job_work_from_home          search_location      job_posted_date  \
# 528548               False              Netherlands  2023-04-16 11:43:30
# 531813               False  Illinois, United States  2023-04-26 19:02:54
# 11980                False                   Poland  2023-08-22 13:23:49
# 134496               False                    India  2023-12-06 08:09:08
# 359312               False           United Kingdom  2023-01-16 23:54:06
#
#         job_no_degree_mention  job_health_insurance     job_country  \
# 528548                  False                 False     Netherlands
# 531813                   True                  True   United States
# 11980                   False                 False          Poland
# 134496                  False                 False           India
# 359312                   True                 False  United Kingdom
#
#        salary_rate  salary_year_avg  salary_hour_avg  \
# 528548        None              NaN              NaN
# 531813        None              NaN              NaN
# 11980         None              NaN              NaN
# 134496        None              NaN              NaN
# 359312        None              NaN              NaN
#
#                       company_name  \
# 528548                  Hiber B.V.
# 531813                   Assetmark
# 11980   Global Enterprise Partners
# 134496                     SutraHR
# 359312              Quinton Davies
#
#                                                job_skills  \
# 528548                                        ['windows']
# 531813  ['sql', 'sql server', 'phoenix', 'tableau', 'm...
# 11980   ['python', 'r', 'sql', 'java', 'javascript', '...
# 134496                                    ['python', 'r']
# 359312  ['sql', 'python', 'java', 'scala', 'golang', '...
#
#                                           job_type_skills
# 528548                                {'os': ['windows']}
# 531813  {'analyst_tools': ['tableau', 'microstrategy']...
# 11980   {'analyst_tools': ['power bi', 'tableau'], 'cl...
# 134496                   {'programming': ['python', 'r']}
# 359312  {'cloud': ['azure', 'aws'], 'libraries': ['pys...

# %%
df["job_posted_date"] = pd.to_datetime(df["job_posted_date"])

# Extract day, month, and year
df["job_posted_day"] = df["job_posted_date"].dt.day_name()
df["job_posted_month"] = df["job_posted_date"].dt.strftime("%B")
df["job_posted_month_no"] = df["job_posted_date"].dt.month
df["job_posted_year"] = df["job_posted_date"].dt.year

# %%
df.sort_values(by=["job_posted_year", "job_posted_month", "job_posted_day"], 
                           ascending=[True, True, True], 
                            inplace=True )

# %%
median_hour_salary = df.salary_hour_avg.median()

df["salary_hour_avg"] = df["salary_hour_avg"].fillna(median_hour_salary)

df.drop_duplicates(subset=['job_title' , 'company_name'], inplace=True)

# %%
df.to_csv("cleaned_data.csv", index=False)
